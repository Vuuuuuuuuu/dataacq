# %%
import os
with  open(os.path.join("ABSTRACT1.rtf"),"r") as file:
  content = file.read()
  print(content)
# Out:
# {\rtf1\ansi\ansicpg1252\deff0\nouicompat\deflang1033{\fonttbl{\f0\fnil\fcharset0 Calibri;}}
# {\*\generator Riched20 10.0.22621}\viewkind4\uc1
# \pard\sa200\sl276\slmult1\qc\f0\fs32\lang9 FINAL YEAR SEMINAR\fs22\par
# \fs36 A BRIEF OVERVEIW OF GaN INTEGRATED CIRCUIT POWER AMPLIFIER\fs22\par
# \b\fs28 GOVERNMEENT ENGINEERING COLLEGE BARTON HILL\b0\par
# DEPARTMENT OF ELECTRICAL AND ELECTRONICS ENGINEERING\par
#
# \pard\sa200\sl276\slmult1 NAME:VAISHNAVU BAIJU\tab\tab\tab GUIDE: Dr. DINESH GOPINATH\par
# REG NO:TRV20EE058\par
#
# \pard\sa200\sl276\slmult1\qc\ul\b\fs32 ABSTRACT\par
#
# \pard\sa200\sl276\slmult1\ulnone\b0\fs28 GaN has been steadily been taking over the electronic idustry with its superior specifications and its application under high voltage due to it being a high-electron mobility transistor. In this presentation we will be goin through the initial stages of GaN and why it is highly sought after and its future prospects.\par
#
# \pard\sa200\sl276\slmult1\qc\fs22\par
# ...

# %%
with open(("ABSTRACT1.rtf"),"r") as file:
  for line in file:
    print(line.strip())
# Out:
# {\rtf1\ansi\ansicpg1252\deff0\nouicompat\deflang1033{\fonttbl{\f0\fnil\fcharset0 Calibri;}}
# {\*\generator Riched20 10.0.22621}\viewkind4\uc1
# \pard\sa200\sl276\slmult1\qc\f0\fs32\lang9 FINAL YEAR SEMINAR\fs22\par
# \fs36 A BRIEF OVERVEIW OF GaN INTEGRATED CIRCUIT POWER AMPLIFIER\fs22\par
# \b\fs28 GOVERNMEENT ENGINEERING COLLEGE BARTON HILL\b0\par
# DEPARTMENT OF ELECTRICAL AND ELECTRONICS ENGINEERING\par
#
# \pard\sa200\sl276\slmult1 NAME:VAISHNAVU BAIJU\tab\tab\tab GUIDE: Dr. DINESH GOPINATH\par
# REG NO:TRV20EE058\par
#
# \pard\sa200\sl276\slmult1\qc\ul\b\fs32 ABSTRACT\par
#
# \pard\sa200\sl276\slmult1\ulnone\b0\fs28 GaN has been steadily been taking over the electronic idustry with its superior specifications and its application under high voltage due to it being a high-electron mobility transistor. In this presentation we will be goin through the initial stages of GaN and why it is highly sought after and its future prospects.\par
#
# \pard\sa200\sl276\slmult1\qc\fs22\par
# ...

# %%
with open(("ABSTRACT1.rtf"),"r") as file:
  print(file.read(10))
# Out:
# {\rtf1\ans

# %%
import os
if os.path.exists("GaN_Integrated_Circuit_Power_Amplifiers_Developments_and_Prospects (2).pdf"):
  os.remove("GaN_Integrated_Circuit_Power_Amplifiers_Developments_and_Prospects (2).pdf")
else:
  print("The file does not exist")

# %%
import pandas as pd
df =pd.read_excel("DSA_Offline_Schedule_HQ TVM_Feb 2025.xlsx",sheet_name="DSA_Offline_Feb_2025_TVM_V2.0")
print(df)
# Out:
#     Unnamed: 0                      Unnamed: 1  \
# 0     Schedule                             NaN
# 1   Session No                  Name of Module
# 2            1                     Life Skills
# 3            2                             NaN
# 4            3  IT Foundation for Data Science
# ..         ...                             ...
# 65          #2                       Review #1
# 66          #3                       Review #2
# 67          #4                       Review #3
# 68          #5                       Review #4
# 69          #6              Final Presentation
#
#                                            Unnamed: 2         Unnamed: 3  \
# 0   Certified Specialist in Data Science and Analy...                NaN
# 1                                     Name of Session  Duration\n(hours)
# 2                                      Life Skills #1                  4
# 3                                      Life Skills #2                  4
# ...

# %%
import pandas as pd
df_json = pd.read_json("config.json", typ = "series")
df_json = df_json.to_frame(name = 'value')
print(df_json.head())
# Out:
#                            value
# model_name   jester_conv_example
# num_classes                    8
# batch_size                    10
# lr                         0.001

# %%
import numpy as np
array = np.array([1,2,3,4,5])
np.save("array.npy", array)
print("array saved as array.npy" )
# Out:
# array saved as array.npy

# %%
array1 = np.array([1,2,3])
array2 = np.array([6,7,8])
np.savez("array.npz", a=array1, b=array2)
print("array saved as array.npz" )
# Out:
# array saved as array.npz

# %%
print(np.load("array.npy"))
c= np.load("array.npz")
c["a"]
# Out:
# [1 2 3 4 5]
# array([1, 2, 3])

# %%
import IPython.display as ipd
ipd.Audio("sample.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
audio_data, sample_rate = librosa.load("sample.wav")
print(audio_data)
print(sample_rate)
# Out:
# [ 1.3411045e-06 -2.0414591e-06  3.6209822e-06 ...  3.8124126e-06
#  -2.9998591e-07  1.7823277e-06]
# 22050

# %%
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(14,5))
librosa.display.waveshow(audio_data, sr=sample_rate)
plt.title("Audio Waveform")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# %%
import yaml
with open(os.path.join("config.yaml")) as file:
  config = yaml.safe_load(file)
  print(config)
# Out:
# {'data_dir': '/data/', 'log_dir': '/logs/', 'log_filename': 'log.csv', 'sampling_rate': '8000', 'threshold': 0.9}

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

image_1 = Image.open('BWOQ1791.JPG')
plt.imshow(image_1)
plt.show()

# %%
g= image_1.convert('L')
plt.imshow(g, cmap='gray')
plt.show()

# %%
import cv2
image = cv2.imread('BWOQ1791.JPG')
resize_image = cv2.resize(image, (1000,1500))
cv2.imwrite("resize_image.jpg",resize_image)
# Out:
# True

# %%
from google.colab.patches import cv2_imshow
image = cv2.imread('BWOQ1791.JPG')

cv2_imshow(image)
cv2_imshow(resize_image)
# Out:
# <PIL.Image.Image image mode=RGB size=150x180>
# <PIL.Image.Image image mode=RGB size=1000x1500>
